# %% [markdown]
# ### Importing Files

# %%
import numpy as np 

import pandas as pd 
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json 

# !conda install -c conda-forge geopy --yes
from geopy.geocoders import Nominatim 

import requests 
from pandas.io.json import json_normalize 


import matplotlib.cm as cm
import matplotlib.colors as colors


from sklearn.cluster import KMeans

# !conda install -c conda-forge folium=0.5.0 --yes 
import folium 

print('Libraries imported.')
# Out:
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.5.11
#   latest version: 4.8.3
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /home/nbuser/anaconda3_501
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     geopy-1.21.0               |             py_0          58 KB  conda-forge
#     conda-4.8.2                |           py36_0         3.0 MB  conda-forge
#     geographiclib-1.50         |             py_0          34 KB  conda-forge
#     python_abi-3.6             |          1_cp36m           4 KB  conda-forge
#     conda-package-handling-1.6.0|   py36h8c4c3a4_2         947 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         4.0 MB
#
# The following NEW packages will be INSTALLED:
#
#     conda-package-handling: 1.6.0-py36h8c4c3a4_2 conda-forge
#     geographiclib:          1.50-py_0            conda-forge
#     geopy:                  1.21.0-py_0          conda-forge
#     python_abi:             3.6-1_cp36m          conda-forge
#
# The following packages will be UPDATED:
#
#     conda:                  4.5.11-py36_0                    --> 4.8.2-py36_0 conda-forge
#
#
# Downloading and Extracting Packages
# geopy-1.21.0         | 58 KB     | ##################################### | 100%
# conda-4.8.2          | 3.0 MB    | ##################################### | 100%
# geographiclib-1.50   | 34 KB     | ##################################### | 100%
# python_abi-3.6       | 4 KB      | ##################################### | 100%
# conda-package-handli | 947 KB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Collecting package metadata (repodata.json): done
# Solving environment: \
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - defaults/linux-64::pytest-doctestplus==0.1.3=py36_0
#   - defaults/linux-64::patsy==0.5.1=py36_0
#   - defaults/linux-64::pytest-arraydiff==0.2=py36h39e3cac_0
#   - defaults/linux-64::hdmedians==0.13=py36h035aef0_0
#   - defaults/linux-64::scikit-learn==0.19.2=py37h4989274_0
#   - defaults/linux-64::bkcharts==0.2=py36_0
#   - defaults/linux-64::blaze==0.11.3=py36_0
#   - https://repo.anaconda.com/pkgs/free/linux-64::pymc==2.3.6=np111py36_2
#   - defaults/linux-64::pandasql==0.7.3=py36_1
#   - defaults/linux-64::mkl_random==1.0.1=py36h4414c95_1
#   - defaults/linux-64::statsmodels==0.9.0=py36h035aef0_0
#   - defaults/linux-64::odo==0.5.1=py36_0
#   - defaults/linux-64::pandas==0.22.0=py36hf484d3e_0
#   - defaults/linux-64::dask==0.19.3=py36_0
#   - defaults/linux-64::scipy==1.1.0=py36hd20e5f9_0
#   - defaults/linux-64::seaborn==0.9.0=py36_0
#   - defaults/linux-64::anaconda==5.3.0=py37_0
#   - defaults/linux-64::pywavelets==1.0.1=py36hdd07704_0
#   - defaults/linux-64::matplotlib==3.0.0=py36h5429711_0
#   - defaults/linux-64::holoviews==1.10.7=py36_0
#   - defaults/linux-64::numpy==1.11.3=py36h1d66e8a_10
#   - defaults/linux-64::pytables==3.4.4=py36he1c29e1_0
#   - defaults/linux-64::h5py==2.8.0=py36h39dcb92_0
#   - pytorch/linux-64::pytorch==1.3.1=py3.6_cpu_0
#   - defaults/linux-64::pytest-astropy==0.4.0=py36_0
#   - defaults/linux-64::imageio==2.4.1=py36_0
#   - defaults/linux-64::astropy==3.0.4=py36h14c3975_0
#   - defaults/linux-64::numexpr==2.6.8=py36hd89afb7_0
#   - defaults/linux-64::mkl_fft==1.0.6=py36h7dd41cf_0
#   - defaults/linux-64::bokeh==0.13.0=py36_0
#   - defaults/linux-64::bottleneck==1.2.1=py36h035aef0_1
#   - defaults/linux-64::gdal==2.3.0=py36h04863e7_1
#   - defaults/linux-64::scikit-image==0.14.0=py37hf484d3e_1
#   - defaults/linux-64::datashape==0.5.4=py36_1
#   - defaults/linux-64::numba==0.40.0=py36h962f231_0
#   - defaults/linux-64::numpy-base==1.11.3=py36h81de0dd_10
#   - pytorch/linux-64::torchvision==0.4.2=py36_cpu
# done
#
# ## Package Plan ##
#
#   environment location: /home/nbuser/anaconda3_501
#
#   added / updated specs:
#     - folium=0.5.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _anaconda_depends-2019.10  |           py36_0           5 KB
#     altair-4.1.0               |             py_1         614 KB  conda-forge
#     anaconda-custom            |           py36_1           3 KB
#     backports.os-0.1.1         |py36h9f0ad1d_1002          15 KB  conda-forge
#     branca-0.4.0               |             py_0          26 KB  conda-forge
#     ca-certificates-2020.4.5.1 |       hecc5488_0         146 KB  conda-forge
#     certifi-2020.4.5.1         |   py36h9f0ad1d_0         151 KB  conda-forge
#     conda-4.8.3                |   py36h9f0ad1d_1         3.0 MB  conda-forge
#     folium-0.5.0               |             py_0          45 KB  conda-forge
#     fsspec-0.7.2               |             py_0          49 KB  conda-forge
#     importlib-metadata-1.6.0   |   py36h9f0ad1d_0          43 KB  conda-forge
#     importlib_metadata-1.6.0   |                0           3 KB  conda-forge
#     joblib-0.14.1              |             py_0         198 KB  conda-forge
#     json5-0.9.0                |             py_0          24 KB  conda-forge
#     jupyterlab_server-0.3.2    |             py_0          23 KB  conda-forge
#     liblief-0.9.0              |       hf8a498c_1         4.2 MB  conda-forge
#     openssl-1.0.2u             |       h516909a_0         3.2 MB  conda-forge
#     py-lief-0.9.0              |   py36he1b5a44_1         1.4 MB  conda-forge
#     pyrsistent-0.16.0          |   py36h8c4c3a4_0          89 KB  conda-forge
#     ripgrep-12.0.1             |       h516909a_1         1.8 MB  conda-forge
#     scikit-image-0.14.2        |   py36hf484d3e_0        24.0 MB  conda-forge
#     scikit-learn-0.20.1        |   py36h4989274_0         5.7 MB
#     soupsieve-1.9.4            |   py36h9f0ad1d_1          58 KB  conda-forge
#     sphinxcontrib-applehelp-1.0.2|             py_0          28 KB  conda-forge
#     sphinxcontrib-devhelp-1.0.2|             py_0          22 KB  conda-forge
#     sphinxcontrib-htmlhelp-1.0.3|             py_0          27 KB  conda-forge
#     sphinxcontrib-jsmath-1.0.1 |             py_0           7 KB  conda-forge
#     sphinxcontrib-qthelp-1.0.3 |             py_0          25 KB  conda-forge
#     sphinxcontrib-serializinghtml-1.1.4|             py_0          24 KB  conda-forge
#     tbb-2020.1                 |       hc9558a2_0         1.4 MB  conda-forge
#     tbb4py-2020.1              |   py36hc9558a2_0         245 KB  conda-forge
#     vincent-0.4.4              |             py_1          28 KB  conda-forge
#     wurlitzer-2.0.0            |   py36h9f0ad1d_1          12 KB  conda-forge
#     zipp-3.1.0                 |             py_0          10 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        46.6 MB
#
# The following NEW packages will be INSTALLED:
#
#   _anaconda_depends  pkgs/main/linux-64::_anaconda_depends-2019.10-py36_0
#   altair             conda-forge/noarch::altair-4.1.0-py_1
#   backports.os       conda-forge/linux-64::backports.os-0.1.1-py36h9f0ad1d_1002
#   branca             conda-forge/noarch::branca-0.4.0-py_0
#   folium             conda-forge/noarch::folium-0.5.0-py_0
#   fsspec             conda-forge/noarch::fsspec-0.7.2-py_0
#   importlib-metadata conda-forge/linux-64::importlib-metadata-1.6.0-py36h9f0ad1d_0
#   importlib_metadata conda-forge/noarch::importlib_metadata-1.6.0-0
#   joblib             conda-forge/noarch::joblib-0.14.1-py_0
#   json5              conda-forge/noarch::json5-0.9.0-py_0
#   jupyterlab_server  conda-forge/noarch::jupyterlab_server-0.3.2-py_0
#   liblief            conda-forge/linux-64::liblief-0.9.0-hf8a498c_1
#   py-lief            conda-forge/linux-64::py-lief-0.9.0-py36he1b5a44_1
#   pyrsistent         conda-forge/linux-64::pyrsistent-0.16.0-py36h8c4c3a4_0
#   ripgrep            conda-forge/linux-64::ripgrep-12.0.1-h516909a_1
#   soupsieve          conda-forge/linux-64::soupsieve-1.9.4-py36h9f0ad1d_1
#   sphinxcontrib-app~ conda-forge/noarch::sphinxcontrib-applehelp-1.0.2-py_0
#   sphinxcontrib-dev~ conda-forge/noarch::sphinxcontrib-devhelp-1.0.2-py_0
#   sphinxcontrib-htm~ conda-forge/noarch::sphinxcontrib-htmlhelp-1.0.3-py_0
#   sphinxcontrib-jsm~ conda-forge/noarch::sphinxcontrib-jsmath-1.0.1-py_0
#   sphinxcontrib-qth~ conda-forge/noarch::sphinxcontrib-qthelp-1.0.3-py_0
#   sphinxcontrib-ser~ conda-forge/noarch::sphinxcontrib-serializinghtml-1.1.4-py_0
#   tbb                conda-forge/linux-64::tbb-2020.1-hc9558a2_0
#   tbb4py             conda-forge/linux-64::tbb4py-2020.1-py36hc9558a2_0
#   vincent            conda-forge/noarch::vincent-0.4.4-py_1
#   wurlitzer          conda-forge/linux-64::wurlitzer-2.0.0-py36h9f0ad1d_1
#   zipp               conda-forge/noarch::zipp-3.1.0-py_0
#
# The following packages will be UPDATED:
#
#   ca-certificates    pkgs/main::ca-certificates-2018.03.07~ --> conda-forge::ca-certificates-2020.4.5.1-hecc5488_0
#   certifi              pkgs/main::certifi-2018.10.15-py36_0 --> conda-forge::certifi-2020.4.5.1-py36h9f0ad1d_0
#   conda                                        4.8.2-py36_0 --> 4.8.3-py36h9f0ad1d_1
#   openssl              pkgs/main::openssl-1.0.2p-h14c3975_0 --> conda-forge::openssl-1.0.2u-h516909a_0
#   scikit-image       pkgs/main::scikit-image-0.14.0-py37hf~ --> conda-forge::scikit-image-0.14.2-py36hf484d3e_0
#   scikit-learn                        0.19.2-py37h4989274_0 --> 0.20.1-py36h4989274_0
#
# The following packages will be DOWNGRADED:
#
#   anaconda                                     5.3.0-py37_0 --> custom-py36_1
#
#
#
# Downloading and Extracting Packages
# sphinxcontrib-jsmath | 7 KB      | ##################################### | 100%
# branca-0.4.0         | 26 KB     | ##################################### | 100%
# importlib-metadata-1 | 43 KB     | ##################################### | 100%
# sphinxcontrib-qthelp | 25 KB     | ##################################### | 100%
# jupyterlab_server-0. | 23 KB     | ##################################### | 100%
# json5-0.9.0          | 24 KB     | ##################################### | 100%
# importlib_metadata-1 | 3 KB      | ##################################### | 100%
# altair-4.1.0         | 614 KB    | ##################################### | 100%
# sphinxcontrib-serial | 24 KB     | ##################################### | 100%
# ca-certificates-2020 | 146 KB    | ##################################### | 100%
# liblief-0.9.0        | 4.2 MB    | ##################################### | 100%
# anaconda-custom      | 3 KB      | ##################################### | 100%
# conda-4.8.3          | 3.0 MB    | ##################################### | 100%
# vincent-0.4.4        | 28 KB     | ##################################### | 100%
# openssl-1.0.2u       | 3.2 MB    | ##################################### | 100%
# scikit-learn-0.20.1  | 5.7 MB    | ##################################### | 100%
# tbb4py-2020.1        | 245 KB    | ##################################### | 100%
# tbb-2020.1           | 1.4 MB    | ##################################### | 100%
# _anaconda_depends-20 | 5 KB      | ##################################### | 100%
# sphinxcontrib-appleh | 28 KB     | ##################################### | 100%
# pyrsistent-0.16.0    | 89 KB     | ##################################### | 100%
# soupsieve-1.9.4      | 58 KB     | ##################################### | 100%
# py-lief-0.9.0        | 1.4 MB    | ##################################### | 100%
# zipp-3.1.0           | 10 KB     | ##################################### | 100%
# joblib-0.14.1        | 198 KB    | ##################################### | 100%
# scikit-image-0.14.2  | 24.0 MB   | ##################################### | 100%
# sphinxcontrib-devhel | 22 KB     | ##################################### | 100%
# fsspec-0.7.2         | 49 KB     | ##################################### | 100%
# folium-0.5.0         | 45 KB     | ##################################### | 100%
# wurlitzer-2.0.0      | 12 KB     | ##################################### | 100%
# certifi-2020.4.5.1   | 151 KB    | ##################################### | 100%
# sphinxcontrib-htmlhe | 27 KB     | ##################################### | 100%
# ripgrep-12.0.1       | 1.8 MB    | ##################################### | 100%
# backports.os-0.1.1   | 15 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Libraries imported.

# %% [markdown]
# ### Downloading the dataset and opening the json file

# %%
# !wget -q -O 'newyork_data.json' https://cocl.us/new_york_dataset
print('Data downloaded!')
# Out:
# Data downloaded!

# %%
with open('newyork_data.json') as json_data:
    newyork_data = json.load(json_data)

# %% [markdown]
# ### Inspecting the features of the data

# %%
#taking a look at the first feature set
neighborhoods_data = newyork_data['features']
neighborhoods_data[0]
# Out:
# {'type': 'Feature',
#  'id': 'nyu_2451_34572.1',
#  'geometry': {'type': 'Point',
#   'coordinates': [-73.84720052054902, 40.89470517661]},
#  'geometry_name': 'geom',
#  'properties': {'name': 'Wakefield',
#   'stacked': 1,
#   'annoline1': 'Wakefield',
#   'annoline2': None,
#   'annoline3': None,
#   'annoangle': 0.0,
#   'borough': 'Bronx',
#   'bbox': [-73.84720052054902,
#    40.89470517661,
#    -73.84720052054902,
#    40.89470517661]}}

# %% [markdown]
# ### Cleaning the data

# %%
# defining the dataframe columns that we need
column_names = ['Borough', 'Neighborhood', 'Latitude', 'Longitude'] 

# instantiate the dataframe
neighborhoods = pd.DataFrame(columns=column_names)

# %%
for data in neighborhoods_data:
    borough = neighborhood_name = data['properties']['borough'] 
    neighborhood_name = data['properties']['name']
        
    neighborhood_latlon = data['geometry']['coordinates']
    neighborhood_lat = neighborhood_latlon[1]
    neighborhood_lon = neighborhood_latlon[0]
    
    neighborhoods = neighborhoods.append({'Borough': borough,
                                          'Neighborhood': neighborhood_name,
                                          'Latitude': neighborhood_lat,
                                          'Longitude': neighborhood_lon}, ignore_index=True)

# %%
neighborhoods.head()
# Out:
#   Borough Neighborhood   Latitude  Longitude
# 0   Bronx    Wakefield  40.894705 -73.847201
# 1   Bronx   Co-op City  40.874294 -73.829939
# 2   Bronx  Eastchester  40.887556 -73.827806
# 3   Bronx    Fieldston  40.895437 -73.905643
# 4   Bronx    Riverdale  40.890834 -73.912585

# %%
#counting the total number of boroughs and neighborhoods
print('The dataframe has {} boroughs and {} neighborhoods.'.format(
        len(neighborhoods['Borough'].unique()),
        neighborhoods.shape[0]
    )
)
# Out:
# The dataframe has 5 boroughs and 306 neighborhoods.

# %%
#show information relating to the borough Manhattan
manhattan_data = neighborhoods[neighborhoods['Borough'] == 'Manhattan']
manhattan_data.head()
# Out:
#        Borough        Neighborhood   Latitude  Longitude
# 6    Manhattan         Marble Hill  40.876551 -73.910660
# 100  Manhattan           Chinatown  40.715618 -73.994279
# 101  Manhattan  Washington Heights  40.851903 -73.936900
# 102  Manhattan              Inwood  40.867684 -73.921210
# 103  Manhattan    Hamilton Heights  40.823604 -73.949688

# %% [markdown]
# ### Crawing Internet (Fouresquare API) for Venues in Manhattan

# %%
CLIENT_ID = ''
CLIENT_SECRET = ''
VERSION = '20180605'

# %%
def foursquare_crawler (neighborhood_list, lat_list, lng_list, LIMIT = 500, radius = 1000):
    result_ds = []
    counter = 0
    for neighborhood, lat, lng in zip(neighborhood_list, lat_list, lng_list):
         
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, CLIENT_SECRET, VERSION, 
            lat, lng, radius, LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        tmp_dict = {}
        tmp_dict['Neighborhood'] = neighborhood;
        tmp_dict['Latitude'] = lat; tmp_dict['Longitude'] = lng;
        tmp_dict['Crawling_result'] = results;
        result_ds.append(tmp_dict)
        counter += 1
        print('{}.'.format(counter))
        print('Data is Obtained, for Neighborhood {} SUCCESSFULLY.'.format(neighborhood))
    return result_ds;

# %%
#crawing neighborhoods in Manhattan
manhattan_dataset = foursquare_crawler(list(manhattan_data['Neighborhood']),
                                        list(manhattan_data['Latitude']),
                                        list(manhattan_data['Longitude']))
# Out:
# 1.
# Data is Obtained, for Neighborhood Marble Hill SUCCESSFULLY.
# 2.
# Data is Obtained, for Neighborhood Chinatown SUCCESSFULLY.
# 3.
# Data is Obtained, for Neighborhood Washington Heights SUCCESSFULLY.
# 4.
# Data is Obtained, for Neighborhood Inwood SUCCESSFULLY.
# 5.
# Data is Obtained, for Neighborhood Hamilton Heights SUCCESSFULLY.
# 6.
# Data is Obtained, for Neighborhood Manhattanville SUCCESSFULLY.
# 7.
# Data is Obtained, for Neighborhood Central Harlem SUCCESSFULLY.
# 8.
# Data is Obtained, for Neighborhood East Harlem SUCCESSFULLY.
# 9.
# Data is Obtained, for Neighborhood Upper East Side SUCCESSFULLY.
# 10.
# Data is Obtained, for Neighborhood Yorkville SUCCESSFULLY.
# 11.
# Data is Obtained, for Neighborhood Lenox Hill SUCCESSFULLY.
# 12.
# Data is Obtained, for Neighborhood Roosevelt Island SUCCESSFULLY.
# 13.
# Data is Obtained, for Neighborhood Upper West Side SUCCESSFULLY.
# 14.
# Data is Obtained, for Neighborhood Lincoln Square SUCCESSFULLY.
# 15.
# Data is Obtained, for Neighborhood Clinton SUCCESSFULLY.
# 16.
# Data is Obtained, for Neighborhood Midtown SUCCESSFULLY.
# 17.
# Data is Obtained, for Neighborhood Murray Hill SUCCESSFULLY.
# 18.
# Data is Obtained, for Neighborhood Chelsea SUCCESSFULLY.
# 19.
# Data is Obtained, for Neighborhood Greenwich Village SUCCESSFULLY.
# 20.
# Data is Obtained, for Neighborhood East Village SUCCESSFULLY.
# 21.
# Data is Obtained, for Neighborhood Lower East Side SUCCESSFULLY.
# 22.
# Data is Obtained, for Neighborhood Tribeca SUCCESSFULLY.
# 23.
# Data is Obtained, for Neighborhood Little Italy SUCCESSFULLY.
# 24.
# Data is Obtained, for Neighborhood Soho SUCCESSFULLY.
# 25.
# Data is Obtained, for Neighborhood West Village SUCCESSFULLY.
# 26.
# Data is Obtained, for Neighborhood Manhattan Valley SUCCESSFULLY.
# 27.
# Data is Obtained, for Neighborhood Morningside Heights SUCCESSFULLY.
# 28.
# Data is Obtained, for Neighborhood Gramercy SUCCESSFULLY.
# 29.
# Data is Obtained, for Neighborhood Battery Park City SUCCESSFULLY.
# 30.
# Data is Obtained, for Neighborhood Financial District SUCCESSFULLY.
# 31.
# Data is Obtained, for Neighborhood Carnegie Hill SUCCESSFULLY.
# 32.
# Data is Obtained, for Neighborhood Noho SUCCESSFULLY.
# 33.
# Data is Obtained, for Neighborhood Civic Center SUCCESSFULLY.
# 34.
# Data is Obtained, for Neighborhood Midtown South SUCCESSFULLY.
# 35.
# Data is Obtained, for Neighborhood Sutton Place SUCCESSFULLY.
# 36.
# Data is Obtained, for Neighborhood Turtle Bay SUCCESSFULLY.
# 37.
# Data is Obtained, for Neighborhood Tudor City SUCCESSFULLY.
# 38.
# Data is Obtained, for Neighborhood Stuyvesant Town SUCCESSFULLY.
# 39.
# Data is Obtained, for Neighborhood Flatiron SUCCESSFULLY.
# 40.
# Data is Obtained, for Neighborhood Hudson Yards SUCCESSFULLY.

# %% [markdown]
# ### Saving foresquare results to avoid repeated calls with foresquare

# %%
import pickle
with open("manhattan_dataset.txt", "wb") as fp:   #Pickling
    pickle.dump(manhattan_dataset, fp)
print('Received Data from Internet is Saved to Computer.')
# Out:
# Received Data from Internet is Saved to Computer.

# %%
with open("manhattan_dataset.txt", "rb") as fp:   # Unpickling
    manhattan_dataset = pickle.load(fp)

# %% [markdown]
# ### Cleaning data received from foresquare database

# %%
# Extracting only the data that we need and are relevant to the rest of the analysis

def get_venue_dataset(foursquare_dataset):
    result_df = pd.DataFrame(columns = ['Neighborhood', 
                                           'Neighborhood Latitude', 'Neighborhood Longitude',
                                          'Venue', 'Venue Summary', 'Venue Category', 'Distance'])

    
    for neigh_dict in foursquare_dataset:
        neigh = neigh_dict['Neighborhood'];
        lat = neigh_dict['Latitude']; lng = neigh_dict['Longitude']
        print('Number of Venues in Coordination "{}" in Negihborhoods is:'.format(neigh))
        print(len(neigh_dict['Crawling_result']))
        
        for venue_dict in neigh_dict['Crawling_result']:
            summary = venue_dict['reasons']['items'][0]['summary']
            name = venue_dict['venue']['name']
            dist = venue_dict['venue']['location']['distance']
            cat =  venue_dict['venue']['categories'][0]['name']
            venlat = venue_dict['venue']['location']['lat']
            venlong = venue_dict['venue']['location']['lng']
            
            
           
            
            result_df = result_df.append({'Neighborhood': neigh, 
                              'Neighborhood Latitude': lat, 'Neighborhood Longitude':lng,
                              'Venue': name, 'Venue Summary': summary, 
                              'Venue Category': cat,'Venue Latitude': venlat, 'Venue Longitude': venlong, 'Distance': dist}, ignore_index = True)
           
    
    return(result_df)

# %%
# Extracting the data
manhattan_venues = get_venue_dataset(manhattan_dataset)
# Out:
# Number of Venues in Coordination "Marble Hill" in Negihborhoods is:
# 82
# Number of Venues in Coordination "Chinatown" in Negihborhoods is:
# 100
# Number of Venues in Coordination "Washington Heights" in Negihborhoods is:
# 100
# Number of Venues in Coordination "Inwood" in Negihborhoods is:
# 100
# Number of Venues in Coordination "Hamilton Heights" in Negihborhoods is:
# 100
# Number of Venues in Coordination "Manhattanville" in Negihborhoods is:
# 100
# Number of Venues in Coordination "Central Harlem" in Negihborhoods is:
# 100
# Number of Venues in Coordination "East Harlem" in Negihborhoods is:
# 100
# Number of Venues in Coordination "Upper East Side" in Negihborhoods is:
# 100
# Number of Venues in Coordination "Yorkville" in Negihborhoods is:
# 100
# Number of Venues in Coordination "Lenox Hill" in Negihborhoods is:
# 100
# Number of Venues in Coordination "Roosevelt Island" in Negihborhoods is:
# 100
# Number of Venues in Coordination "Upper West Side" in Negihborhoods is:
# 100
# Number of Venues in Coordination "Lincoln Square" in Negihborhoods is:
# 100
# Number of Venues in Coordination "Clinton" in Negihborhoods is:
# 100
# Number of Venues in Coordination "Midtown" in Negihborhoods is:
# 100
# Number of Venues in Coordination "Murray Hill" in Negihborhoods is:
# 100
# Number of Venues in Coordination "Chelsea" in Negihborhoods is:
# 100
# Number of Venues in Coordination "Greenwich Village" in Negihborhoods is:
# 100
# Number of Venues in Coordination "East Village" in Negihborhoods is:
# 100
# Number of Venues in Coordination "Lower East Side" in Negihborhoods is:
# 100
# Number of Venues in Coordination "Tribeca" in Negihborhoods is:
# 100
# Number of Venues in Coordination "Little Italy" in Negihborhoods is:
# 100
# Number of Venues in Coordination "Soho" in Negihborhoods is:
# 100
# Number of Venues in Coordination "West Village" in Negihborhoods is:
# 100
# Number of Venues in Coordination "Manhattan Valley" in Negihborhoods is:
# 100
# Number of Venues in Coordination "Morningside Heights" in Negihborhoods is:
# 100
# Number of Venues in Coordination "Gramercy" in Negihborhoods is:
# 100
# Number of Venues in Coordination "Battery Park City" in Negihborhoods is:
# 100
# Number of Venues in Coordination "Financial District" in Negihborhoods is:
# 100
# Number of Venues in Coordination "Carnegie Hill" in Negihborhoods is:
# 100
# Number of Venues in Coordination "Noho" in Negihborhoods is:
# 100
# Number of Venues in Coordination "Civic Center" in Negihborhoods is:
# 100
# Number of Venues in Coordination "Midtown South" in Negihborhoods is:
# 100
# Number of Venues in Coordination "Sutton Place" in Negihborhoods is:
# 100
# Number of Venues in Coordination "Turtle Bay" in Negihborhoods is:
# 100
# Number of Venues in Coordination "Tudor City" in Negihborhoods is:
# 100
# Number of Venues in Coordination "Stuyvesant Town" in Negihborhoods is:
# 100
# Number of Venues in Coordination "Flatiron" in Negihborhoods is:
# 100
# Number of Venues in Coordination "Hudson Yards" in Negihborhoods is:
# 100

# %% [markdown]
# ### A summary of our dataset

# %%
manhattan_venues.head()
# Out:
#   Neighborhood  Neighborhood Latitude  Neighborhood Longitude          Venue  \
# 0  Marble Hill              40.876551               -73.91066    Bikram Yoga
# 1  Marble Hill              40.876551               -73.91066       Arturo's
# 2  Marble Hill              40.876551               -73.91066  Tibbett Diner
# 3  Marble Hill              40.876551               -73.91066    Sam's Pizza
# 4  Marble Hill              40.876551               -73.91066      Starbucks
#
#           Venue Summary Venue Category Distance  Venue Latitude  \
# 0  This spot is popular    Yoga Studio      376       40.876844
# 1  This spot is popular    Pizza Place      240       40.874412
# 2  This spot is popular          Diner      452       40.880404
# 3  This spot is popular    Pizza Place      516       40.879435
# 4  This spot is popular    Coffee Shop      441       40.877531
#
#    Venue Longitude
# 0       -73.906204
# 1       -73.910271
# 2       -73.908937
# 3       -73.905859
# 4       -73.905582

# %% [markdown]
# ### Saving cleaned data as a csv file

# %%
# Saving the file
manhattan_venues.to_csv('manhattan_venues.csv')

# %%
# Loading the data
manhattan_venues = pd.read_csv('manhattan_venues.csv')

# %% [markdown]
# ### Identifying unique venue categories in the dataset

# %%
print('There are {} uniques categories.'.format(len(manhattan_venues['Venue Category'].unique())))

print('Here is the list of different categories:')
list(manhattan_venues['Venue Category'].unique())
# Out:
# There are 307 uniques categories.
# Here is the list of different categories:
# ['Yoga Studio',
#  'Pizza Place',
#  'Diner',
#  'Coffee Shop',
#  'Mexican Restaurant',
#  'Donut Shop',
#  'Caribbean Restaurant',
#  'Pub',
#  'Athletics & Sports',
#  'Supermarket',
#  'Gym',
#  'Gourmet Shop',
#  'Café',
#  'Department Store',
#  'Sandwich Place',
#  'Spanish Restaurant',
#  'Seafood Restaurant',
#  'Scenic Lookout',
#  'Discount Store',
#  'Tennis Stadium',
#  'Deli / Bodega',
#  'Supplement Shop',
#  'Bakery',
#  'Thai Restaurant',
#  'Miscellaneous Shop',
#  'Pharmacy',
#  'Cuban Restaurant',
#  'Playground',
#  'Candy Store',
#  'Lounge',
#  'American Restaurant',
#  'Ice Cream Shop',
#  'Park',
#  'Wine Shop',
#  'Flower Shop',
#  'Steakhouse',
#  'Bank',
#  'Video Game Store',
#  'Kids Store',
#  'Bar',
#  'Thrift / Vintage Store',
#  'Breakfast Spot',
#  'Latin American Restaurant',
#  'Rental Car Location',
#  'Trail',
#  'Bus Station',
#  'Salon / Barbershop',
#  'Intersection',
#  'River',
#  'Lake',
#  'Garden',
#  'Chinese Restaurant',
#  'Greek Restaurant',
#  'Hotel',
#  'Cocktail Bar',
#  'Hotpot Restaurant',
#  'Spa',
#  'Indie Movie Theater',
#  'English Restaurant',
#  'New American Restaurant',
#  'Museum',
#  'Roof Deck',
#  'Asian Restaurant',
#  'Tea Room',
#  'Cosmetics Shop',
#  'Historic Site',
#  'Organic Grocery',
#  'Paper / Office Supplies Store',
#  'Furniture / Home Store',
#  'Malay Restaurant',
#  'Shoe Store',
#  'Gift Shop',
#  'Vietnamese Restaurant',
#  'Music Venue',
#  'Speakeasy',
#  'Noodle House',
#  'Dumpling Restaurant',
#  'Dim Sum Restaurant',
#  'Optical Shop',
#  'Boutique',
#  'Juice Bar',
#  'Shanghai Restaurant',
#  'Cantonese Restaurant',
#  'Dessert Shop',
#  'Australian Restaurant',
#  'Pie Shop',
#  'Karaoke Bar',
#  'Empanada Restaurant',
#  'Pet Store',
#  'Bubble Tea Shop',
#  'Bagel Shop',
#  'Record Shop',
#  'Jewelry Store',
#  'Gym / Fitness Center',
#  'French Restaurant',
#  'Movie Theater',
#  'Vegetarian / Vegan Restaurant',
#  'Wine Bar',
#  'Restaurant',
#  'Italian Restaurant',
#  'Burger Joint',
#  'Market',
#  'Ramen Restaurant',
#  'Pet Café',
#  'Tapas Restaurant',
#  'Pool',
#  'Liquor Store',
#  'Frozen Yogurt Shop',
#  'Indian Restaurant',
#  'Mobile Phone Shop',
#  'Lighthouse',
#  'Grocery Store',
#  'Middle Eastern Restaurant',
#  'Fast Food Restaurant',
#  'Plaza',
#  'Accessories Store',
#  'Sushi Restaurant',
#  'Arepa Restaurant',
#  'Dog Run',
#  'Convenience Store',
#  'Rest Area',
#  'Farmers Market',
#  'Bistro',
#  'Veterinarian',
#  'Basketball Court',
#  'Venezuelan Restaurant',
#  'Mediterranean Restaurant',
#  'Beer Garden',
#  'History Museum',
#  'Art Museum',
#  'Cupcake Shop',
#  'Nightclub',
#  'Shipping Store',
#  'Smoke Shop',
#  'Japanese Restaurant',
#  'School',
#  'Food Truck',
#  'State / Provincial Park',
#  'Tennis Court',
#  'Gastropub',
#  'Ethiopian Restaurant',
#  'Whisky Bar',
#  'Southern / Soul Food Restaurant',
#  'Cycle Studio',
#  'Track',
#  'Taco Place',
#  'African Restaurant',
#  'Event Space',
#  'College Theater',
#  'Dance Studio',
#  'Theater',
#  'Food & Drink Shop',
#  'BBQ Joint',
#  'Climbing Gym',
#  'Bike Trail',
#  'Japanese Curry Restaurant',
#  'Art Gallery',
#  'Fried Chicken Joint',
#  'Jazz Club',
#  'Falafel Restaurant',
#  'Sporting Goods Shop',
#  'Arts & Crafts Store',
#  'Library',
#  'Beer Bar',
#  'Bookstore',
#  'Public Art',
#  'Cafeteria',
#  'Comfort Food Restaurant',
#  'Fountain',
#  'Street Art',
#  'Outdoor Sculpture',
#  "Doctor's Office",
#  'Moroccan Restaurant',
#  'Field',
#  'Hawaiian Restaurant',
#  'Garden Center',
#  'Hotel Bar',
#  'Burrito Place',
#  'Exhibit',
#  'Sculpture Garden',
#  'Salad Place',
#  "Women's Store",
#  'Turkish Restaurant',
#  'Electronics Store',
#  'Clothing Store',
#  'Monument / Landmark',
#  'Snack Place',
#  'Kitchen Supply Store',
#  'Beer Store',
#  'Butcher',
#  'Health & Beauty Service',
#  'Hot Dog Joint',
#  'Daycare',
#  'Peruvian Restaurant',
#  'Massage Studio',
#  'Gymnastics Gym',
#  'Health Food Store',
#  'Czech Restaurant',
#  'Club House',
#  'Pilates Studio',
#  'Cambodian Restaurant',
#  'Waterfront',
#  'Outdoors & Recreation',
#  'Tram Station',
#  'Baseball Field',
#  'Residential Building (Apartment / Condo)',
#  'Persian Restaurant',
#  'Shoe Repair',
#  'Tiki Bar',
#  'Sports Bar',
#  'Israeli Restaurant',
#  'Planetarium',
#  'Drugstore',
#  'Science Museum',
#  'Souvenir Shop',
#  'Cultural Center',
#  'Concert Hall',
#  'South Indian Restaurant',
#  'Soup Place',
#  'Opera House',
#  'Performing Arts Venue',
#  'College Arts Building',
#  'Circus',
#  'Community Center',
#  'Comedy Club',
#  'Building',
#  'Music School',
#  'Food Court',
#  'Caucasian Restaurant',
#  'Indie Theater',
#  'Pier',
#  'Camera Store',
#  'Resort',
#  "Men's Store",
#  'Nail Salon',
#  'Tailor Shop',
#  'Boxing Gym',
#  'Train Station',
#  'Office',
#  'Comic Shop',
#  'TV Station',
#  'Toy / Game Store',
#  'Theme Restaurant',
#  'Church',
#  'Jewish Restaurant',
#  'Sake Bar',
#  'Korean Restaurant',
#  'Wings Joint',
#  'Fish Market',
#  'Photography Studio',
#  'Physical Therapist',
#  'Flea Market',
#  'Cheese Shop',
#  'Golf Driving Range',
#  'General Entertainment',
#  'Martial Arts Dojo',
#  'Recreation Center',
#  'Udon Restaurant',
#  'Lebanese Restaurant',
#  'Financial or Legal Service',
#  'Outdoor Supply Store',
#  'Scandinavian Restaurant',
#  'Swiss Restaurant',
#  'Filipino Restaurant',
#  'Ukrainian Restaurant',
#  'Pet Service',
#  'Eastern European Restaurant',
#  'Bridge',
#  'Creperie',
#  'Rock Club',
#  'Poke Place',
#  'Argentinian Restaurant',
#  'Volleyball Court',
#  'Mini Golf',
#  'Molecular Gastronomy Restaurant',
#  'Bike Rental / Bike Share',
#  'Antique Shop',
#  'Chocolate Shop',
#  'Board Shop',
#  'Austrian Restaurant',
#  'Hostel',
#  'Halal Restaurant',
#  'Arcade',
#  'Tech Startup',
#  'Harbor / Marina',
#  'Shopping Mall',
#  'Memorial Site',
#  'Auditorium',
#  'Lingerie Store',
#  'Laundry Service',
#  'High School',
#  'Pedestrian Plaza',
#  'Heliport',
#  'Kosher Restaurant',
#  'Reservoir',
#  'Basketball Stadium',
#  'Piano Bar',
#  'Bike Shop',
#  'Adult Boutique',
#  'Spiritual Center',
#  'Synagogue',
#  'Tourist Information Center',
#  'Duty-free Shop',
#  'Non-Profit',
#  'German Restaurant',
#  'Hobby Shop',
#  'Music Store']

# %% [markdown]
# ### Manually selecting features for food places in Manhattan

# %%
food_places=[
    
'Neighborhood',
    'Neighborhood Latitude',
    'Neighborhood Longitude',
    'Venue',
    'Venue Latitude',
    'Venue Longitude',
   

 'Pizza Place',
 'Diner',
 'Coffee Shop',
 'Mexican Restaurant',
 'Donut Shop',
 'Caribbean Restaurant',
    
 'Café',
 'Sandwich Place',
 'Spanish Restaurant',
 'Seafood Restaurant',




 'Thai Restaurant',


 'Cuban Restaurant',



 'American Restaurant',
 'Ice Cream Shop',

 'Wine Shop',

 'Steakhouse',




 'Breakfast Spot',
 'Latin American Restaurant',









 'Chinese Restaurant',
 'Greek Restaurant',

 'Cocktail Bar',


 'New American Restaurant',

 'Asian Restaurant',

 'Malay Restaurant',
 'Snack Place',


 'Vietnamese Restaurant',
 'Austrian Restaurant',

 'Dumpling Restaurant',



 'Shanghai Restaurant',
 'Dessert Shop',
 'Cantonese Restaurant',

 'Australian Restaurant',
 'Pie Shop',
 'Empanada Restaurant',
    
 'Bagel Shop',
 'Hotpot Restaurant',

 'Noodle House',




 'Food Court',

 'French Restaurant',

 'Restaurant',
 'Italian Restaurant',
 'Burger Joint',

 'Ramen Restaurant',

 'Tapas Restaurant',


 'Frozen Yogurt Shop',
 'Indian Restaurant',



 'Middle Eastern Restaurant',
 'Fast Food Restaurant',




 'Arepa Restaurant',





 'Bistro',
 'Veterinarian',

 'Venezuelan Restaurant',
 'Mediterranean Restaurant',

 'Sushi Restaurant',






 'Japanese Restaurant',

 'Food Truck',



 'Ethiopian Restaurant',

 'Southern / Soul Food Restaurant',


 'Taco Place',
 'African Restaurant',




 'Food & Drink Shop',
 'BBQ Joint',


 'Japanese Curry Restaurant',

 'Fried Chicken Joint',

 'Falafel Restaurant',






 'Cafeteria',
 'Comfort Food Restaurant',



 'Moroccan Restaurant',

 'Hawaiian Restaurant',


 'Burrito Place',


 'Salad Place',


 'Turkish Restaurant',
 
 'Vegetarian / Vegan Restaurant',




 'Hot Dog Joint',
 'German Restaurant',

 'Peruvian Restaurant',


 'Health Food Store',
 'Czech Restaurant',


 'English Restaurant',


 'Cambodian Restaurant',



 'Persian Restaurant',



 'Israeli Restaurant',







 'Caucasian Restaurant',

    
    
 
 
 'Jewish Restaurant',
 
 'Korean Restaurant',
 
 
 'Udon Restaurant',
 
 'Lebanese Restaurant',
 
 'Soup Place',
 'Scandinavian Restaurant',
 'Swiss Restaurant',
 
 'Ukrainian Restaurant',
 'Filipino Restaurant',
 'Argentinian Restaurant',

 'Eastern European Restaurant',
 

 'Molecular Gastronomy Restaurant',



 'Wings Joint',
 

 'Halal Restaurant',
 

 'Kosher Restaurant',
]

# %% [markdown]
# ### Updating the dataframe

# %%
manhattan_foodplaces = pd.read_csv('manhattan_venues.csv')
manhattan_foodplaces = manhattan_foodplaces[manhattan_foodplaces['Venue Category'].isin(food_places)]
manhattan_foodplaces = manhattan_foodplaces.drop(['Unnamed: 0','Unnamed: 0.1','Unnamed: 0.1.1'], axis=1)

manhattan_foodplaces.head()
# Out:
#   Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 1  Marble Hill              40.876551               -73.91066
# 2  Marble Hill              40.876551               -73.91066
# 3  Marble Hill              40.876551               -73.91066
# 4  Marble Hill              40.876551               -73.91066
# 5  Marble Hill              40.876551               -73.91066
#
#                   Venue         Venue Summary      Venue Category  Distance  \
# 1              Arturo's  This spot is popular         Pizza Place       240
# 2         Tibbett Diner  This spot is popular               Diner       452
# 3           Sam's Pizza  This spot is popular         Pizza Place       516
# 4             Starbucks  This spot is popular         Coffee Shop       441
# 5  Estrellita Poblana V  This spot is popular  Mexican Restaurant       509
#
#    Venue Latitude  Venue Longitude
# 1       40.874412       -73.910271
# 2       40.880404       -73.908937
# 3       40.879435       -73.905859
# 4       40.877531       -73.905582
# 5       40.879687       -73.906257

# %% [markdown]
# ### Visualizing the data based on venue longitude and latitudes

# %%
import matplotlib
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(16,8))
cmap=plt.cm.rainbow
norm = matplotlib.colors.BoundaryNorm(np.arange(0,10,1), cmap.N)
plt.scatter(manhattan_foodplaces['Venue Longitude'], manhattan_foodplaces['Venue Latitude'],
            cmap=cmap, norm=norm, s=150, edgecolor='none')
plt.xlabel('Longitude', fontsize=18)
plt.ylabel('Latitude', fontsize=18)
plt.grid()
plt.show()

# %% [markdown]
# ### Run k means clustering to cluster the data into 5 clusters

# %%
kmeans_1 = KMeans(n_clusters=5)
# Using fit_predict to cluster the dataset
X = manhattan_foodplaces[['Venue Longitude','Venue Latitude']].values
predictions = kmeans_1.fit_predict(X)

# %%
clustered = pd.concat([manhattan_foodplaces.reset_index(), 
                       pd.DataFrame({'Cluster':predictions})], 
                      axis=1)

# %%
clustered.drop('index', axis=1, inplace=True)

# %%
conditions = [
    clustered['Cluster'] == 0, 
    clustered['Cluster'] == 1,
    clustered['Cluster'] == 2,
    clustered['Cluster'] == 3,
    clustered['Cluster'] == 4,]

# %%
clustered.sort_values(by=['Cluster']).head()
# Out:
#       Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 1907  Hudson Yards              40.756658              -74.000111
# 816    Murray Hill              40.748303              -73.978332
# 817    Murray Hill              40.748303              -73.978332
# 819        Chelsea              40.744035              -74.003116
# 820        Chelsea              40.744035              -74.003116
#
#                        Venue         Venue Summary       Venue Category  \
# 1907  New York Pizza Suprema  This spot is popular          Pizza Place
# 816                Roberta's  This spot is popular          Pizza Place
# 817        Grace Street Cafe  This spot is popular         Dessert Shop
# 819    Intelligentsia Coffee  This spot is popular          Coffee Shop
# 820                 Sushinao  This spot is popular  Japanese Restaurant
#
#       Distance  Venue Latitude  Venue Longitude  Cluster
# 1907       845       40.750124       -73.994992        0
# 816        695       40.754465       -73.976939        0
# 817        701       40.747708       -73.986608        0
# 819        283       40.745926       -74.005376        0
# 820        257       40.742033       -74.001581        0

# %% [markdown]
# ### Visualizing the clusters

# %%
cmap=plt.cm.rainbow
norm = matplotlib.colors.BoundaryNorm(np.arange(0,10,1), cmap.N)
plt.scatter(clustered['Venue Longitude'], clustered['Venue Latitude'], c=clustered['Cluster'],
            cmap=cmap, norm=norm, s=150, edgecolor='none')
plt.colorbar(ticks=np.linspace(0,9,10))
centers = kmeans_1.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c='black', s=100, alpha=0.3);
plt.xlabel('Longitude', fontsize=14)
plt.ylabel('Latitude', fontsize=14)
plt.title('k-means clustering results (n_clusters=5)', fontsize=14)
plt.grid()
plt.show()

# %% [markdown]
# ### Finding out the cluster with the highest number of food places

# %%
most_food_places = clustered['Cluster'].value_counts()

most_food_places
# Out:
# 3    675
# 0    435
# 4    367
# 2    286
# 1    145
# Name: Cluster, dtype: int64

# %% [markdown]
# ### Getting the centers of each cluster

# %%
cluster_centers = kmeans_1.cluster_centers_
cluster_centers
# Out:
# array([[-73.98359565,  40.75053021],
#        [-73.92433599,  40.86251647],
#        [-73.95296225,  40.81105125],
#        [-73.99614713,  40.72221541],
#        [-73.95938559,  40.7760763 ]])

# %% [markdown]
# ### Creating a table summarizing the clusters along with the latitude and longitude of the centers of the clusters

# %%
c = {'Cluster Number': [3, 0, 4, 2, 1], 'Number Of Food Places In Cluster':[675, 435, 367, 286, 145], 'Cluster Center Longitude': [-73.98359565,-73.92433599,-73.95296225,-73.99614713,-73.95938559], 'Cluster Center Latitude': [40.75053021,40.86251647,40.81105125,40.72221541, 40.7760763 ]}
                                
clusdata = pd.DataFrame(data=c)
                                
clusdata
# Out:
#    Cluster Number  Number Of Food Places In Cluster  Cluster Center Longitude  \
# 0               3                               675                -73.983596
# 1               0                               435                -73.924336
# 2               4                               367                -73.952962
# 3               2                               286                -73.996147
# 4               1                               145                -73.959386
#
#    Cluster Center Latitude
# 0                40.750530
# 1                40.862516
# 2                40.811051
# 3                40.722215
# 4                40.776076

# %% [markdown]
# ### Visualizing the center of Cluster 1

# %%
latitude = 40.750530
longitude = -73.983596

venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) 

folium.features.CircleMarker(
    [latitude, longitude],
    radius=5,
    color='red',
    popup='Cluster 1 Center',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Results: The best cluster is cluster 3 with 675 food places in the cluster. I recommend the owner to set up office near the center of cluster 3 to get the best location in town based on the number of food places around the area.
